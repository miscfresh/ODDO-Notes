# %% [markdown]
# # **RDKit Workshop with Dr. Liu - 03/262026**

# %% [markdown]
# ## *Introduction to SMILES*
#
# Lowkey pulled up late but from I gather:
# - SMILES uses arrays to model molecules
# - "Molecule Graphs -> Adjacency Matrix" whatever that means; way to define and encode structure properties
# -
