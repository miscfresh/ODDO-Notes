# %% [markdown]
# # **Article Review for Raymond Pho & Lawton Long**
# *~Prepping for initial meeting for the Denard Chemical Engineering Lab~*

# %% [markdown]
# ## **Background Context**
#
# I've been trying to join a research lab since I first transferred to UF. It's been particularly difficult thanks to coming in to the college with no connections to any prof as a junior. I only started really making progress in senior year where I was able to meet and talk to Dr. Carl A Denard at the chemistry club's Molecular Mixer (thanks my goats). His lab is in chemical engineering, and I'll likely be working with Raymond Pho and Lawton Long. Their research revolves around strategies to combat protein aggregation in human disease. I'm supposed to meet with them sometime this week so I wanna prepare and read through some (if not most) of their papers to get a good understanding on what exactly they study and the methods they use to do so.

# %% [markdown]
# ## **Random Little Notes lol**
#
# Dr. Denard explained what they do really well honestly. YESS and HARP basically function by overclocking yeast to generate a massive library of mutated version of a specific protease. The goal is to find mutants that:
# - ***DO*** cleave our target sequence
# - ***DO NOT*** cleave sequences we want to avoid
#
# This is basically the directed evolution thing thats mentioned in basically every paper (synthetic driven natural-selection). HARP is a bit different because it's tailored for discovery of inhibitors and nanobodys that bind to proteases. Either way, you're generating massive mutant libraries using the yeast, then using fluorescent sorting (FACS) to pick 'winners'. Machine learning is being used to predict which mutations should be targeted, and kind of help which direction to drive the protease mutations.

# %% [markdown]
# ## **What is protein aggregation?**
#
# Protein aggregation is what occurs when misfolded proteins - full or partial conformational dissonance - clump together with other healthy proteins, forming disordered or ordered assemblies that cells typically cannot use and almost certainly cannot get rid of. There are generally considered to be two types of aggregates: amorphous aggregates & amyloid fibrils. Amorphous aggregates are basically just disorganized clumps, amyloid fibrils are more relevant as they are highly ordered and form cross-β sheet structures. This ordering and cross-β sheet structures makes them thermodynamically stable, highly resistant to proteases, and tend to propagate by templating futher misfolding.
#
# ### *How does this happen?*
#
# Cells typically have "quality control" parameters to prevent this, for example:
# - Molecular chaperones: His70, His90, etc. ensure proper folding and fixing conformationally stressed proteins
# - Ubiquitin-Proteosome System (UPS): Tags & degrades misfolded proteins
# - Autophagy: Cells automatic system for recycling damaged components (like misfolded proteins)
#
# Aggregation only occurs when all of these systems are overwhelmed, either by genetic mutation or simply sheer concentrations of an aggregation-prone sequence.
#
# ### *Protein Aggregation in Human Diseases*
#
# Protein aggregation is an identifying feature of a whole class of diseases called *proteinopathies*. Some examples are:
# - Alzheimers: Aggregation of amyloid-β (Aβ) into plaques extraceullularly, and tau (a protein that's supposed to stabilize the internatl structure of neurons) in neurofibrillary tangles intraceulluarly
# - Parkinsons: α-synuclein aggregates into Lewy Bodies (abnormal clumps) in dopeminergic neurons
# - ALS/FTD:  TDP-43 and FUS mislocalizes from the nucleus and form into cytoplasmic inclusions
# - Huntingtons: polyglutamine (polyQ) expansion in huntingtin drives aggregation; longer repeats = earlier onset
#
# ### *How are they toxic?*
#
# This is where stuff gets complicated, because the mechanism in which aggregation occurs still isn't really known. The leading hypothesis is that oligomers (100> monomer units) are the toxic species, as opposed to the fibrils themselves. Oligomers can pass through membranes easier, disrupt synaptic functions, and trigger inflammation. Some suspect that the large fibrous units might actually be protective in a sense by sequestering away the more dangerous soluble forms.

# %% [markdown]
# ## **Article Review**
#
# ### *Protease Engineering - Approaches, tools, and emerging trends*
#
# *Introduction*
# Proteases catalyze one of the most fundamental biochemical reactions: hydrolysis of peptide bonds in peptides and proteins. They make up ~2% of an organism's proteome (thats a ton of proteases) and play critical roles in nearly all cellular processes. As such, they're key targets in numerous therapeutic strategies for a variety of ailments. Harnessing the power of proteases has been instrumental in a variety of fields [blah blah this genuinely doesn't matter too much right now]. Proteases have become integral in basically every single domain of molecular biotechnology, driving a surge of interest in protease engineering. [Going to skip forward a lot because some stuff isn't relevant (I already know)]. Despite advances made in reprogramming core protease attributes like substrate specificity, activation mechanisms, and catalytic efficiency, little progress was made in early protease research. Traditional protease engineering was narrow sighted and we ultimately found that rational subsite redesign yielded limited success. Experiments done modifying prebuilt proteins - like trypsin to chymotrypsin - found that:
# - active site mutations alone cannot impart proteases with novel activities and specificities
# - subsite residue crosstalk influences substrate recognition
# - mutations far away from active sites (ex. exosites, allosteric sites) play a role in substrate binding and catalytic efficiency
#
#
#
# Protease Engineering Fundamentals:
# - Proteases are critical enzymes compromising ~2% of an organisms proteome with roles in basically all cellular processes
# - Traditional protease redesign - like converting trypsin to chymotrypsin (modifying existing proteins) - has shown little success
# - Modern approaches combine directed evolution, structural biology, and machine learning
# - Substrate specificity involves complex interactions beyond just the active site; mutations far from active site and subsite talk are crucial
#     + Allosteric regulation, exosite binding, etc.
#
# Key Platforms & Tools - YESS platform
# - YESS: Yeast ER Sequestration Screen for engineering protease specificity
#     + co-developed by Dr. Denard
#     + ER acts as a specialized sealed (sequestered) environment to isolate/store/process target substrates
# - YESS 2.0 enables precise control over selection conditions
# - Uses yeast surface display with fluorescent readouts
# - Has acheived 5000+ fold specificity switches
# - Allows counterselection to avoid promiscuous variants
#
# Disease-Relevant Applications
# - *Protein Aggregation & Neurodegeneration*
#     + Amyloid-β (Aβ) engineering: multiple examples of engineering proteases to cleave Aβ peptides associated with Alzheimer's
#     + Kallikrein 7 (KLK7) engineered for 30-fold improved Aβ cleavage using PrECISE platform
